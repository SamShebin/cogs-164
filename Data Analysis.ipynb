# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
sns.set()
sns.set_context('talk')

import warnings
warnings.filterwarnings('ignore')

import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/shebinsam/Desktop/cogs/cogs-164/Data Analysis.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/Users/shebinsam/Desktop/cogs/cogs-164/Data%20Analysis.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> import warnings
#      <a href='vscode-notebook-cell:/Users/shebinsam/Desktop/cogs/cogs-164/Data%20Analysis.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a> warnings.filterwarnings('ignore')
# ---> <a href='vscode-notebook-cell:/Users/shebinsam/Desktop/cogs/cogs-164/Data%20Analysis.ipynb#W0sZmlsZQ%3D%3D?line=13'>14</a> import patsy
#      <a href='vscode-notebook-cell:/Users/shebinsam/Desktop/cogs/cogs-164/Data%20Analysis.ipynb#W0sZmlsZQ%3D%3D?line=14'>15</a> import statsmodels.api as sm
# ...

# %%
df = pd.read_csv('Copy of Fear of Failure–Survey (COGS 164) (Responses) - Form Responses 1(1).csv')

# %%
df['FoF Total'] = df['FoF Total']*100
df['Motivation Total'] = df['Motivation Total']*100

# %%
df.describe()
df.head(5)
# Out:
#             Timestamp  FoAF  Goal Anxiety  High Stakes   Future Plans  \
# 0   3/6/2024 20:19:19     1             2             2             1
# 1  2/29/2024 19:03:31     3             2             4             2
# 2   3/2/2024 15:45:12     4             4             4             4
# 3   3/2/2024 21:44:03     5             5             5             5
# 4   3/6/2024 13:28:41     4             4             4             5
#
#    Self-Value  Control  FoF Total  Motivation to Succeed  \
# 0           1        2  30.000000                      4
# 1           2        4  56.666667                      4
# 2           4        4  80.000000                      3
# 3           3        5  93.333333                      5
# 4           4        3  80.000000                      5
#
#    Intrinsic Motivation  ...  Priority for Learning(P/NP)  Seeking Help  \
# 0                     4  ...                          3.0             3
# ...

# %%
sns.lmplot(x='FoF Total', y='Motivation Total', data=df, 
                fit_reg=True, height=6, aspect=2);

# %%
sns.lmplot(x='FoF Total', y='Motivation Total', data=df,
           fit_reg=True, height=10, aspect=2);

# %%
df2 = df.iloc[:, :15]

# %%
sns.lmplot(x='FoF Total', y='Cheating', data=df2,
           fit_reg=True, height=6, aspect=2);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_493/3131392797.py in <module>
# ----> 1 sns.lmplot(x='FoF Total', y='Cheating', data=df2,
#       2            fit_reg=True, height=6, aspect=2);
#
# NameError: name 'df2' is not defined
